# %%
import json
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
import os
import imageio
from collections import deque, namedtuple
from til_environment.gridworld import RewardNames

# --- Configuration (Adjust these as needed) ---
# Environment specific (match your game)
MAP_SIZE_X = 16
MAP_SIZE_Y = 16
MAX_STEPS_PER_EPISODE = 100 # Max steps in one round of the game

# Neural Network Hyperparameters (from rl_agent_python_v1)
INPUT_FEATURES = 288  # 7*5*8 (viewcone) + 4 (direction) + 2 (location) + 1 (scout) + 1 (step)
HIDDEN_LAYER_1_SIZE = 256
HIDDEN_LAYER_2_SIZE = 256
HIDDEN_LAYER_3_SIZE = 256
OUTPUT_ACTIONS = 5  # 0:Forward, 1:Backward, 2:TurnL, 3:TurnR, 4:Stay

# Training Hyperparameters
BUFFER_SIZE = int(1e5)  # Replay buffer size
BATCH_SIZE = 32         # Minibatch size for training
GAMMA = 0.99            # Discount factor
LEARNING_RATE = 1e-4    # Learning rate for the optimizer
TARGET_UPDATE_EVERY = 100 # How often to update the target network (in steps)
UPDATE_EVERY = 4        # How often to run a learning step (in steps)

# Epsilon-greedy exploration parameters (for training)
EPSILON_START = 0.25
EPSILON_END = 0.01
EPSILON_DECAY = 0.9999 # Multiplicative decay factor per episode/fixed number of steps

# PER Parameters
PER_ALPHA = 0.6  # Prioritization exponent (0 for uniform, 1 for full prioritization)
PER_BETA_START = 0.4 # Initial importance sampling exponent
PER_BETA_FRAMES = int(1e5) # Number of frames over which beta is annealed to 1.0
PER_EPSILON = 1e-6 # Small constant to ensure non-zero priority

# Device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Reward shaping
CUSTOM_REWARDS_DICT = {
    # --- Positive Rewards (Scout achieves goals) ---
    RewardNames.SCOUT_MISSION: +5.0,      # Big positive reward for completing the main objective
    RewardNames.SCOUT_RECON: +1.0,         # Positive reward for collecting recon (intermediate goal)
    RewardNames.SCOUT_TRUNCATION: +5.0,   # Positive reward for surviving the entire episode without capture

    # --- Negative Rewards (Scout fails or undesirable behaviour) ---
    RewardNames.SCOUT_CAPTURED: -30.0,     # Huge negative reward for being captured (terminal state)
    # Note: GUARD_WINS and GUARD_CAPTURES also imply the Scout was captured,
    # but SCOUT_CAPTURED is explicitly for the Scout agent itself.
    # You could potentially add small penalties here if you want, but SCOUT_CAPTURED is the primary signal.
    # RewardNames.GUARD_WINS: -10.0, # Optional: small additional penalty if Guards collectively win
    # RewardNames.GUARD_CAPTURES: -10.0, # Optional: small additional penalty if a Guard captures

    RewardNames.SCOUT_STEP: -0.02,          # Small negative reward per step (time penalty, encourages efficiency)
    RewardNames.WALL_COLLISION: -10.0,       # Penalty for colliding with a wall (discourages invalid moves)
    RewardNames.AGENT_COLLIDER: -10.0,       # Penalty for colliding *into* another agent (discourages bumping)
    RewardNames.AGENT_COLLIDEE: -10.0,       # Small penalty for being collided *into* (suggests being in a bad position)
    RewardNames.STATIONARY_PENALTY: -0.2,   # Small penalty for staying still (encourages movement unless strategically beneficial)

    # --- Rewards for other agents (generally keep at 0 or default for Scout's dict) ---
    # These would be relevant if training Guards, but not the Scout directly via this dict.
    RewardNames.GUARD_WINS: 0.0,
    RewardNames.GUARD_CAPTURES: 0.0,
    RewardNames.GUARD_TRUNCATION: 0.0, # This corresponds to SCOUT_TRUNCATION for the Scout
    RewardNames.GUARD_STEP: 0.0,
}
    

# --- SumTree for Prioritized Replay Buffer ---
class SumTree:
    """
    A SumTree is a binary tree data structure where the value of a parent node
    is the sum of its children. It is used for efficient sampling from a
    distribution. Leaf nodes store priorities, and internal nodes store sums.
    """
    def __init__(self, capacity):
        self.capacity = capacity
        self.tree = np.zeros(2 * capacity - 1) # Tree storage
        self.data = np.zeros(capacity, dtype=object) # Data storage (transitions)
        self.data_pointer = 0 # Current position to write new data
        self.n_entries = 0 # Current number of entries in the buffer

    def add(self, priority, data):
        """Add priority score and data to the tree."""
        tree_idx = self.data_pointer + self.capacity - 1
        self.data[self.data_pointer] = data
        self.update(tree_idx, priority)

        self.data_pointer += 1
        if self.data_pointer >= self.capacity:
            self.data_pointer = 0 # Cycle back to the beginning

        if self.n_entries < self.capacity:
            self.n_entries += 1

    def update(self, tree_idx, priority):
        """Update priority of a node and propagate changes upwards."""
        change = priority - self.tree[tree_idx]
        self.tree[tree_idx] = priority
        # Propagate the change up the tree
        while tree_idx != 0:
            tree_idx = (tree_idx - 1) // 2
            self.tree[tree_idx] += change

    def get_leaf(self, value):
        """Find sample on leaf node based on a cumulative sum value."""
        parent_idx = 0
        while True:
            left_child_idx = 2 * parent_idx + 1
            right_child_idx = left_child_idx + 1
            if left_child_idx >= len(self.tree): # Reached leaf
                leaf_idx = parent_idx
                break
            else:
                if value <= self.tree[left_child_idx]:
                    parent_idx = left_child_idx
                else:
                    value -= self.tree[left_child_idx]
                    parent_idx = right_child_idx
        
        data_idx = leaf_idx - self.capacity + 1
        return leaf_idx, self.tree[leaf_idx], self.data[data_idx]

    @property
    def total_priority(self):
        return self.tree[0]

# --- Prioritized Replay Buffer ---
Experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])

class PrioritizedReplayBuffer:
    def __init__(self, capacity, alpha=PER_ALPHA):
        self.tree = SumTree(capacity)
        self.alpha = alpha # Controls how much prioritization is used (0=uniform, 1=full)
        self.max_priority = 1.0 # Max priority for new experiences

    def add(self, state, action, reward, next_state, done):
        """Adds a new experience to the buffer with max priority."""
        experience = Experience(state, action, reward, next_state, done)
        self.tree.add(self.max_priority, experience)

    def sample(self, batch_size, beta=PER_BETA_START):
        """
        Samples a batch of experiences from the buffer.
        Args:
            batch_size (int): Number of experiences to sample.
            beta (float): Importance-sampling exponent.
        Returns:
            tuple: (experiences, indices, weights)
        """
        batch_idx = np.empty(batch_size, dtype=np.int32)
        batch_data = np.empty(batch_size, dtype=object)
        weights = np.empty(batch_size, dtype=np.float32)

        priority_segment = self.tree.total_priority / batch_size
        
        for i in range(batch_size):
            a = priority_segment * i
            b = priority_segment * (i + 1)
            value = np.random.uniform(a, b)
            index, priority, data = self.tree.get_leaf(value)
            
            sampling_probabilities = priority / self.tree.total_priority
            weights[i] = np.power(self.tree.n_entries * sampling_probabilities, -beta) # (N * P(i))^-beta
            batch_idx[i] = index
            batch_data[i] = data
        
        weights /= weights.max() # Normalize for stability

        states, actions, rewards, next_states, dones = zip(*[e for e in batch_data])

        states = torch.from_numpy(np.vstack(states)).float().to(DEVICE)
        actions = torch.from_numpy(np.vstack(actions)).long().to(DEVICE)
        rewards = torch.from_numpy(np.vstack(rewards)).float().to(DEVICE)
        next_states = torch.from_numpy(np.vstack(next_states)).float().to(DEVICE)
        dones = torch.from_numpy(np.vstack(dones).astype(np.uint8)).float().to(DEVICE)
        
        return (states, actions, rewards, next_states, dones), batch_idx, torch.from_numpy(weights).float().to(DEVICE)

    def update_priorities(self, batch_indices, td_errors):
        """Updates the priorities of sampled experiences."""
        priorities = np.abs(td_errors) + PER_EPSILON # Add epsilon to ensure non-zero priority
        priorities = np.power(priorities, self.alpha)
        
        for idx, priority in zip(batch_indices, priorities):
            self.tree.update(idx, priority)
            self.max_priority = max(self.max_priority, priority) # Update max_priority

    def __len__(self):
        return self.tree.n_entries

# --- Deep Q-Network (DQN) Model (same as in rl_agent_python_v1) ---
class DQN(nn.Module):
    def __init__(self, input_dim, hidden_dim1, hidden_dim2, hidden_dim3, output_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim1)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim1, hidden_dim2)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(hidden_dim2, hidden_dim3)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(hidden_dim3, output_dim)

    def forward(self, x):
        x = self.relu1(self.fc1(x))
        x = self.relu2(self.fc2(x))
        x = self.relu3(self.fc3(x))
        x = self.fc4(x)
        return x

# --- Trainable RL Agent ---
class TrainableRLAgent:
    def __init__(self, model_load_path=None, model_save_path="trained_dqn_model.pth"):
        self.device = DEVICE
        print(f"Using device: {self.device}")

        self.policy_net = DQN(INPUT_FEATURES, HIDDEN_LAYER_1_SIZE, HIDDEN_LAYER_2_SIZE, HIDDEN_LAYER_3_SIZE, OUTPUT_ACTIONS).to(self.device)
        self.target_net = DQN(INPUT_FEATURES, HIDDEN_LAYER_1_SIZE, HIDDEN_LAYER_2_SIZE, HIDDEN_LAYER_3_SIZE, OUTPUT_ACTIONS).to(self.device)
        
        if model_load_path and os.path.exists(model_load_path):
            try:
                self.policy_net.load_state_dict(torch.load(model_load_path, map_location=self.device))
                print(f"Loaded pre-trained policy_net from {model_load_path}")
            except Exception as e:
                print(f"Error loading model from {model_load_path}: {e}. Initializing with random weights.")
                self.policy_net.apply(self._initialize_weights)
        else:
            print(f"No model path provided or path {model_load_path} does not exist. Initializing policy_net with random weights.")
            self.policy_net.apply(self._initialize_weights)

        self.target_net.load_state_dict(self.policy_net.state_dict()) # Initialize target_net with policy_net weights
        self.target_net.eval() # Target network is only for inference

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=LEARNING_RATE)
        self.memory = PrioritizedReplayBuffer(BUFFER_SIZE, alpha=PER_ALPHA)
        
        self.model_save_path = model_save_path
        self.t_step = 0 # Counter for triggering learning and target network updates
        self.beta = PER_BETA_START
        self.beta_increment_per_sampling = (1.0 - PER_BETA_START) / PER_BETA_FRAMES
        self.global_step = 0


    def _initialize_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)

    def _unpack_viewcone_tile(self, tile_value): # Same as in rl_agent_python_v1
        tile_features = []
        tile_features.append(float(tile_value & 0b01)) 
        tile_features.append(float((tile_value & 0b10) >> 1))
        for i in range(2, 8):
            tile_features.append(float((tile_value >> i) & 1))
        return tile_features

    def process_observation(self, observation_dict): # Same as in rl_agent_python_v1
        processed_features = []
        viewcone = observation_dict.get("viewcone", [])
        for r in range(7):
            for c in range(5):
                tile_value = viewcone[r][c] if r < len(viewcone) and c < len(viewcone[r]) else 0
                processed_features.extend(self._unpack_viewcone_tile(tile_value))
        
        direction = observation_dict.get("direction", 0)
        direction_one_hot = [0.0] * 4
        if 0 <= direction < 4: direction_one_hot[direction] = 1.0
        processed_features.extend(direction_one_hot)

        location = observation_dict.get("location", [0, 0])
        norm_x = location[0] / MAP_SIZE_X if MAP_SIZE_X > 0 else 0.0
        norm_y = location[1] / MAP_SIZE_Y if MAP_SIZE_Y > 0 else 0.0
        processed_features.extend([norm_x, norm_y])

        scout_role = float(observation_dict.get("scout", 0))
        processed_features.append(scout_role)

        step = observation_dict.get("step", 0)
        norm_step = step / MAX_STEPS_PER_EPISODE if MAX_STEPS_PER_EPISODE > 0 else 0.0
        processed_features.append(norm_step)
        
        # Ensure correct feature length (should be INPUT_FEATURES)
        if len(processed_features) != INPUT_FEATURES:
            # This indicates an issue with feature processing or constants
            raise ValueError(f"Feature length mismatch. Expected {INPUT_FEATURES}, got {len(processed_features)}")

        return np.array(processed_features, dtype=np.float32) # Return as numpy array for buffer

    def select_action(self, state_np, epsilon=0.0):
        """
        Selects an action using epsilon-greedy policy.
        Args:
            state_np (np.ndarray): Processed state as a numpy array.
            epsilon (float): Exploration rate.
        Returns:
            int: Selected action.
        """
        if random.random() > epsilon:
            state_tensor = torch.from_numpy(state_np).float().unsqueeze(0).to(self.device)
            self.policy_net.eval() # Set to evaluation mode for action selection
            with torch.no_grad():
                action_values = self.policy_net(state_tensor)
            self.policy_net.train() # Set back to training mode
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(OUTPUT_ACTIONS))

    def step(self, state, action, reward, next_state, done):
        self.memory.add(state, action, reward, next_state, done)

        # Increment the global step counter every time step is called for the agent
        self.global_step += 1

        # This part correctly triggers the LEARNING step every UPDATE_EVERY steps
        self.t_step = (self.t_step + 1) % UPDATE_EVERY
        if self.t_step == 0:
            if len(self.memory) > BATCH_SIZE:
                # Perform the learning step
                experiences, indices, weights = self.memory.sample(BATCH_SIZE, beta=self.beta)
                self.learn(experiences, indices, weights, GAMMA)
                # Anneal beta, typically done per learning step or total step
                self.beta = min(1.0, self.beta + self.beta_increment_per_sampling)


        # This part correctly triggers the TARGET NETWORK UPDATE every TARGET_UPDATE_EVERY global steps
        # Use the global_step counter for this check
        if self.global_step % TARGET_UPDATE_EVERY == 0:
             self.update_target_net() # This method performs the hard copy


    def learn(self, experiences, indices, importance_sampling_weights, gamma):
        """
        Update value parameters using given batch of experience tuples.
        Q_targets = r + γ * Q_target(s', argmax_a Q_policy(s', a))
        Args:
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples
            indices (np.ndarray): indices of these experiences in the SumTree
            importance_sampling_weights (torch.Tensor): weights for IS
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # Get max predicted Q values (for next states) from policy network
        # This is for Double DQN: action selection from policy_net, evaluation from target_net
        q_next_policy = self.policy_net(next_states).detach().max(1)[1].unsqueeze(1)
        # Get Q values for next_states from target_net using actions selected by policy_net
        q_targets_next = self.target_net(next_states).detach().gather(1, q_next_policy)
        
        # Compute Q targets for current states 
        q_targets = rewards + (gamma * q_targets_next * (1 - dones))

        # Get expected Q values from policy_net
        q_expected = self.policy_net(states).gather(1, actions)

        # Compute TD errors for PER
        td_errors = (q_targets - q_expected).abs().cpu().detach().numpy().flatten()
        self.memory.update_priorities(indices, td_errors)

        # Compute loss (element-wise multiplication with IS weights)
        loss = (importance_sampling_weights * nn.MSELoss(reduction='none')(q_expected, q_targets)).mean()
        
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 1.0) # Gradient clipping
        self.optimizer.step()


    def update_target_net(self):
        """Soft update model parameters: θ_target = τ*θ_local + (1 - τ)*θ_target"""
        # For hard update:
        self.target_net.load_state_dict(self.policy_net.state_dict())
        print("Updated target network.")

    def save_model(self):
        torch.save(self.policy_net.state_dict(), self.model_save_path)
        print(f"Model saved to {self.model_save_path}")

    def reset_state(self): # For compatibility with potential stateful components, not used in this DQN
        pass


# --- Main Training Loop (Example) ---
def train_agent(env_module, num_episodes=2000, novice_track=False, load_model_from=None, save_model_to="trained_dqn_agent.pth", render_mode=None, video_folder=None):
    """
    Main training loop for the RL agent.
    Args:
        env_module: The imported environment module (e.g., til_environment.gridworld).
        num_episodes (int): Number of episodes to train for.
        novice_track (bool): If true, uses the novice environment settings.
        load_model_from (str, optional): Path to load a pre-trained model.
        save_model_to (str): Path to save the trained model.
    """
    # Initialize your game environment
    # This assumes your 'til_environment.gridworld' has an 'env' function
    # that returns a PettingZoo-like environment.
    env = env_module.env(env_wrappers=[], render_mode=render_mode, novice=novice_track, rewards_dict=CUSTOM_REWARDS_DICT)
    
    # Create video folder if needed
    if render_mode == "rgb_array" and video_folder:
        os.makedirs(video_folder, exist_ok=True)
    
    # Assuming your agent is always the first one in possible_agents
    # Adjust if your setup is different or if you want to train a specific agent
    my_agent_id = env.possible_agents[3] 
    print(f"Training agent: {my_agent_id}")
    print(f"Action space for {my_agent_id}: {env.action_space(my_agent_id)}")
    print(f"Observation space for {my_agent_id}: {env.observation_space(my_agent_id)}")

    agent = TrainableRLAgent(model_load_path=load_model_from, model_save_path=save_model_to)
    
    scores_deque = deque(maxlen=100) # For tracking recent scores
    scores = [] # List of scores from all episodes
    epsilon = EPSILON_START
    total_steps_taken = 0

    for i_episode in range(1, num_episodes + 1):
        env.reset() # Reset environment at the start of each episode
        agent.reset_state() # Reset agent's internal state if any (not for this DQN)
        
        # The environment interaction loop from your test script
        current_rewards_this_episode = {agent_id: 0 for agent_id in env.possible_agents}
        
        # Get initial observation for our agent
        # This part needs careful handling with PettingZoo's agent_iter
        # We need to get the first observation for our agent
        
        # The loop below processes all agents. We only train `my_agent_id`.
        # We need to store the state for `my_agent_id` to pass to `agent.step`
        
        last_observation_for_my_agent = None
        
        # Initialize frame list ONLY if this episode is a recording episode
        episode_frames = []
        should_record_video = (render_mode == "rgb_array" and i_episode % 100 == 0) # Flag to control recording
        
        for pet_agent_id in env.agent_iter(): # PettingZoo's iterator
            observation, reward, termination, truncation, info = env.last()
            
            # Capture frame ONLY if recording is enabled for this episode
            if should_record_video: # Use the flag
                try:
                    frame = env.render()
                    if frame is not None:
                        episode_frames.append(frame)
                except Exception as e:
                    print(f"\nWarning: Could not render frame for episode {i_episode}, step {agent.global_step}: {e}")
                    traceback.print_exc()
 
            # Accumulate rewards for all agents for this step
            for ag_id in env.agents: # env.agents are live agents in current step
                 current_rewards_this_episode[ag_id] += env.rewards.get(ag_id, 0)

            done = termination or truncation

            if done: # If an agent is done, it might not take an action
                action = None # PettingZoo expects None if agent is done
            elif pet_agent_id == my_agent_id:
                # It's our agent's turn
                # 1. Process observation
                obs_dict = {k: v if isinstance(v, (int, float)) else v.tolist() for k, v in observation.items()}
                current_state_np = agent.process_observation(obs_dict)
                
                # 2. Store previous transition if available
                if last_observation_for_my_agent is not None:
                    # last_observation_for_my_agent = (prev_state, prev_action, prev_reward_for_my_agent)
                    prev_state_np, prev_action, prev_reward = last_observation_for_my_agent
                    # The reward for the (s,a) pair is what we received *after* taking action 'a' in state 's'
                    # which is the 'reward' variable from env.last() *now*
                    agent.step(prev_state_np, prev_action, reward, current_state_np, done)
                    total_steps_taken +=1

                # 3. Select action
                action = agent.select_action(current_state_np, epsilon)
                
                # 4. Store current state, action, and this step's reward for the *next* transition
                last_observation_for_my_agent = (current_state_np, action, reward) # reward here is for the current (s,a)

            else:
                # Other agents take random actions (or use their own policies if implemented)
                if env.action_space(pet_agent_id) is not None:
                     action = env.action_space(pet_agent_id).sample()
                else:
                    action = None # Should not happen if agent is not done

            env.step(action) # Step the environment with the chosen action (or None)
            
            if done and pet_agent_id == my_agent_id and last_observation_for_my_agent is not None:
                # If our agent is done, we need to record the final transition
                prev_state_np, prev_action, _ = last_observation_for_my_agent 
                # The final reward is `reward` from env.last() when done is true
                # The next_state is not critical as it's a terminal state, can be zeros or current_state_np
                final_next_state_np = np.zeros_like(prev_state_np) # Or current_state_np
                agent.step(prev_state_np, prev_action, reward, final_next_state_np, True)
                total_steps_taken +=1
                last_observation_for_my_agent = None # Reset for next episode start

        # End of episode
        episode_score = current_rewards_this_episode[my_agent_id]
        scores_deque.append(episode_score)
        scores.append(episode_score)
        
        epsilon = max(EPSILON_END, EPSILON_DECAY * epsilon) # Decay epsilon
        
        # Save video at the end of the episode ONLY if frames were collected
        if should_record_video and video_folder and len(episode_frames) > 0: # Check the flag
            video_path = os.path.join(video_folder, f"episode_{i_episode:06d}.mp4") # Use 6 digits for episode number
            try:
                # imageio needs the frames to be in (T, H, W, C) format, which env.render() provides
                imageio.mimsave(video_path, episode_frames, fps=30) # Adjust fps as needed
                print(f"\nSaved video for episode {i_episode} to {video_path}") # Print on a new line after progress
            except Exception as e:
                print(f"\nWarning: Could not save video for episode {i_episode} to {video_path}: {e}")
                traceback.print_exc()
       
        print(f'\rEpisode {i_episode}\tAverage Score (last 100): {np.mean(scores_deque):.2f}\tEpsilon: {epsilon:.4f}\tTotal Steps: {total_steps_taken}', end="")
        if i_episode % 100 == 0:
            print(f'\rEpisode {i_episode}\tAverage Score (last 100): {np.mean(scores_deque):.2f}\tEpsilon: {epsilon:.4f}\tTotal Steps: {total_steps_taken}')
            agent.save_model()
        
        if np.mean(scores_deque) >= 2000.0: # Example condition to stop training
            print(f'\nEnvironment solved in {i_episode-100:d} episodes!\tAverage Score: {np.mean(scores_deque):.2f}')
            agent.save_model()
            break
            
    env.close()
    return scores


if __name__ == '__main__':
    # --- HOW TO USE ---
    # 1. Make sure you have 'til_environment' and its 'gridworld' module accessible.
    #    (e.g., it's in your PYTHONPATH or the same directory)
    # 2. Install PyTorch: pip install torch
    # 3. Run this script: python your_training_script_name.py
    import time
    start = time.time()
    # Example:
    try:
        from til_environment import gridworld # Assuming this is your environment module
        print("Successfully imported til_environment.gridworld")
        
        # Start training
        # Set load_model_from to a .pth file to continue training or fine-tune
        # Set save_model_to to where you want the final model to be saved
        trained_scores = train_agent(
            gridworld, 
            num_episodes=100000, # Adjust as needed
            novice_track=False, # Or True for the Novice track map
            load_model_from="agent03_100k_eps.pth", # "trained_dqn_agent.pth" to resume
            save_model_to="agent03_new_100k_eps.pth",
            render_mode="rgb_array",
            video_folder="./rl_renders_agent03_new"
        )
        print("Training finished.")

        # You can add plotting for scores if you like:
        # import matplotlib.pyplot as plt
        # plt.plot(np.arange(len(trained_scores)), trained_scores)
        # plt.ylabel('Score')
        # plt.xlabel('Episode #')
        # plt.show()

    except ImportError:
        print("Could not import 'til_environment.gridworld'.")
        print("Please ensure the environment module is correctly set up and accessible.")
    except Exception as e:
        print(f"An error occurred during training: {e}")
        import traceback
        traceback.print_exc()

    end = time.time()
    print("Time taken = ", end-start)
    print(f"Time taken = {end-start:.4f} seconds")
# Out:
# Successfully imported til_environment.gridworld
# Training agent: player_3
# Action space for player_3: Discrete(5)
# Observation space for player_3: Dict('direction': Discrete(4), 'location': Box(0, 16, (2,), uint8), 'scout': Discrete(2), 'step': Discrete(100), 'viewcone': Box(0, 255, (7, 5), uint8))
# Using device: cuda
# No model path provided or path agent03_100k_eps.pth does not exist. Initializing policy_net with random weights.
# Updated target network.
# Episode 1	Average Score (last 100): -280.60	Epsilon: 0.2500	Total Steps: 100Updated target network.
# Episode 2	Average Score (last 100): -156.00	Epsilon: 0.2500	Total Steps: 200Updated target network.
# Episode 3	Average Score (last 100): -107.80	Epsilon: 0.2499	Total Steps: 300Updated target network.
# Episode 4	Average Score (last 100): -89.49	Epsilon: 0.2499	Total Steps: 400Updated target network.
# Episode 5	Average Score (last 100): -79.72	Epsilon: 0.2499	Total Steps: 500Updated target network.
# Episode 6	Average Score (last 100): -69.86	Epsilon: 0.2499	Total Steps: 600Updated target network.
# Episode 7	Average Score (last 100): -65.77	Epsilon: 0.2498	Total Steps: 700Updated target network.
# Episode 9	Average Score (last 100): -49.55	Epsilon: 0.2498	Total Steps: 876Updated target network.
# Episode 10	Average Score (last 100): -48.72	Epsilon: 0.2498	Total Steps: 976Updated target network.
# Episode 11	Average Score (last 100): -44.36	Epsilon: 0.2497	Total Steps: 1076Updated target network.
# Episode 12	Average Score (last 100): -39.03	Epsilon: 0.2497	Total Steps: 1176Updated target network.
# Episode 13	Average Score (last 100): -36.87	Epsilon: 0.2497	Total Steps: 1276Updated target network.
# Episode 14	Average Score (last 100): -38.71	Epsilon: 0.2497	Total Steps: 1376Updated target network.
# Episode 15	Average Score (last 100): -54.49	Epsilon: 0.2496	Total Steps: 1476Updated target network.
# Episode 16	Average Score (last 100): -51.18	Epsilon: 0.2496	Total Steps: 1576Updated target network.
# Episode 17	Average Score (last 100): -50.62	Epsilon: 0.2496	Total Steps: 1676Updated target network.
# Episode 18	Average Score (last 100): -50.63	Epsilon: 0.2496	Total Steps: 1776Updated target network.
# Episode 19	Average Score (last 100): -50.09	Epsilon: 0.2495	Total Steps: 1876Updated target network.
# Episode 20	Average Score (last 100): -49.29	Epsilon: 0.2495	Total Steps: 1976Updated target network.
# Episode 21	Average Score (last 100): -49.23	Epsilon: 0.2495	Total Steps: 2076Updated target network.
# Episode 22	Average Score (last 100): -48.84	Epsilon: 0.2495	Total Steps: 2176Updated target network.
# Episode 23	Average Score (last 100): -47.42	Epsilon: 0.2494	Total Steps: 2276Updated target network.
# Episode 24	Average Score (last 100): -47.24	Epsilon: 0.2494	Total Steps: 2376Updated target network.
# Episode 25	Average Score (last 100): -47.84	Epsilon: 0.2494	Total Steps: 2476Updated target network.
# Episode 26	Average Score (last 100): -46.05	Epsilon: 0.2494	Total Steps: 2576Updated target network.
# Episode 28	Average Score (last 100): -43.80	Epsilon: 0.2493	Total Steps: 2697Updated target network.
# Episode 29	Average Score (last 100): -43.34	Epsilon: 0.2493	Total Steps: 2797Updated target network.
# Episode 30	Average Score (last 100): -42.26	Epsilon: 0.2493	Total Steps: 2897Updated target network.
# Episode 31	Average Score (last 100): -41.33	Epsilon: 0.2492	Total Steps: 2997Updated target network.
# Episode 32	Average Score (last 100): -38.88	Epsilon: 0.2492	Total Steps: 3097Updated target network.
# Episode 33	Average Score (last 100): -37.72	Epsilon: 0.2492	Total Steps: 3197Updated target network.
# Episode 34	Average Score (last 100): -38.10	Epsilon: 0.2492	Total Steps: 3297Updated target network.
# Episode 35	Average Score (last 100): -37.89	Epsilon: 0.2491	Total Steps: 3397Updated target network.
# Episode 36	Average Score (last 100): -36.30	Epsilon: 0.2491	Total Steps: 3497Updated target network.
# Episode 37	Average Score (last 100): -35.90	Epsilon: 0.2491	Total Steps: 3597Updated target network.
# Episode 38	Average Score (last 100): -34.99	Epsilon: 0.2491	Total Steps: 3697Updated target network.
# Episode 39	Average Score (last 100): -34.27	Epsilon: 0.2490	Total Steps: 3797Updated target network.
# Episode 40	Average Score (last 100): -34.77	Epsilon: 0.2490	Total Steps: 3897Updated target network.
# Episode 41	Average Score (last 100): -35.41	Epsilon: 0.2490	Total Steps: 3997Updated target network.
# Episode 42	Average Score (last 100): -34.94	Epsilon: 0.2490	Total Steps: 4097Updated target network.
# Episode 43	Average Score (last 100): -35.34	Epsilon: 0.2489	Total Steps: 4197Updated target network.
# Episode 44	Average Score (last 100): -32.62	Epsilon: 0.2489	Total Steps: 4297Updated target network.
# Episode 45	Average Score (last 100): -32.09	Epsilon: 0.2489	Total Steps: 4397Updated target network.
# Episode 46	Average Score (last 100): -31.62	Epsilon: 0.2489	Total Steps: 4497Updated target network.
# Episode 47	Average Score (last 100): -31.63	Epsilon: 0.2488	Total Steps: 4597Updated target network.
# Episode 48	Average Score (last 100): -30.73	Epsilon: 0.2488	Total Steps: 4697Updated target network.
# Episode 49	Average Score (last 100): -30.34	Epsilon: 0.2488	Total Steps: 4797Updated target network.
# Episode 50	Average Score (last 100): -30.34	Epsilon: 0.2488	Total Steps: 4897Updated target network.
# Episode 51	Average Score (last 100): -29.97	Epsilon: 0.2487	Total Steps: 4997Updated target network.
# Episode 52	Average Score (last 100): -27.71	Epsilon: 0.2487	Total Steps: 5097Updated target network.
# Episode 53	Average Score (last 100): -27.96	Epsilon: 0.2487	Total Steps: 5197Updated target network.
# Episode 54	Average Score (last 100): -27.66	Epsilon: 0.2487	Total Steps: 5297Updated target network.
# Episode 55	Average Score (last 100): -27.36	Epsilon: 0.2486	Total Steps: 5397Updated target network.
# Episode 56	Average Score (last 100): -27.36	Epsilon: 0.2486	Total Steps: 5431Updated target network.
# Episode 57	Average Score (last 100): -27.94	Epsilon: 0.2486	Total Steps: 5531Updated target network.
# Episode 58	Average Score (last 100): -28.68	Epsilon: 0.2486	Total Steps: 5631Updated target network.
# Episode 59	Average Score (last 100): -28.71	Epsilon: 0.2485	Total Steps: 5731Updated target network.
# Episode 60	Average Score (last 100): -28.36	Epsilon: 0.2485	Total Steps: 5831Updated target network.
# Episode 61	Average Score (last 100): -27.92	Epsilon: 0.2485	Total Steps: 5931Updated target network.
# Episode 62	Average Score (last 100): -27.81	Epsilon: 0.2485	Total Steps: 6031Updated target network.
# Episode 63	Average Score (last 100): -27.55	Epsilon: 0.2484	Total Steps: 6131Updated target network.
# Episode 64	Average Score (last 100): -26.61	Epsilon: 0.2484	Total Steps: 6231Updated target network.
# Episode 65	Average Score (last 100): -26.82	Epsilon: 0.2484	Total Steps: 6331Updated target network.
# Episode 66	Average Score (last 100): -26.90	Epsilon: 0.2484	Total Steps: 6431Updated target network.
# Episode 67	Average Score (last 100): -27.16	Epsilon: 0.2483	Total Steps: 6531Updated target network.
# Episode 68	Average Score (last 100): -26.19	Epsilon: 0.2483	Total Steps: 6631Updated target network.
# Episode 69	Average Score (last 100): -26.57	Epsilon: 0.2483	Total Steps: 6731Updated target network.
# Episode 70	Average Score (last 100): -26.68	Epsilon: 0.2483	Total Steps: 6831Updated target network.
# Episode 71	Average Score (last 100): -26.89	Epsilon: 0.2482	Total Steps: 6931Updated target network.
# Episode 72	Average Score (last 100): -26.70	Epsilon: 0.2482	Total Steps: 7031Updated target network.
# Episode 73	Average Score (last 100): -26.84	Epsilon: 0.2482	Total Steps: 7131Updated target network.
# Episode 74	Average Score (last 100): -27.05	Epsilon: 0.2482	Total Steps: 7231Updated target network.
# Episode 75	Average Score (last 100): -27.26	Epsilon: 0.2481	Total Steps: 7331Updated target network.
# Episode 77	Average Score (last 100): -25.62	Epsilon: 0.2481	Total Steps: 7493Updated target network.
# Episode 78	Average Score (last 100): -25.31	Epsilon: 0.2481	Total Steps: 7593Updated target network.
# Episode 79	Average Score (last 100): -25.65	Epsilon: 0.2480	Total Steps: 7693Updated target network.
# Episode 80	Average Score (last 100): -24.95	Epsilon: 0.2480	Total Steps: 7793Updated target network.
# Episode 81	Average Score (last 100): -25.00	Epsilon: 0.2480	Total Steps: 7893Updated target network.
# Episode 82	Average Score (last 100): -25.08	Epsilon: 0.2480	Total Steps: 7993Updated target network.
# Episode 83	Average Score (last 100): -25.69	Epsilon: 0.2479	Total Steps: 8093Updated target network.
# Episode 84	Average Score (last 100): -24.75	Epsilon: 0.2479	Total Steps: 8193Updated target network.
# Episode 85	Average Score (last 100): -25.06	Epsilon: 0.2479	Total Steps: 8293Updated target network.
# Episode 86	Average Score (last 100): -25.49	Epsilon: 0.2479	Total Steps: 8393Updated target network.
# Episode 87	Average Score (last 100): -25.49	Epsilon: 0.2478	Total Steps: 8493Updated target network.
# Episode 88	Average Score (last 100): -25.11	Epsilon: 0.2478	Total Steps: 8593Updated target network.
# Episode 89	Average Score (last 100): -25.18	Epsilon: 0.2478	Total Steps: 8693Updated target network.
# Episode 90	Average Score (last 100): -25.39	Epsilon: 0.2478	Total Steps: 8793Updated target network.
# Episode 91	Average Score (last 100): -25.14	Epsilon: 0.2477	Total Steps: 8893Updated target network.
# Episode 92	Average Score (last 100): -24.78	Epsilon: 0.2477	Total Steps: 8993Updated target network.
# Episode 93	Average Score (last 100): -24.62	Epsilon: 0.2477	Total Steps: 9093Updated target network.
# Episode 94	Average Score (last 100): -24.48	Epsilon: 0.2477	Total Steps: 9193Updated target network.
# Episode 95	Average Score (last 100): -24.25	Epsilon: 0.2476	Total Steps: 9293Updated target network.
# Episode 96	Average Score (last 100): -23.17	Epsilon: 0.2476	Total Steps: 9393Updated target network.
# Episode 97	Average Score (last 100): -23.08	Epsilon: 0.2476	Total Steps: 9493Updated target network.
# Episode 98	Average Score (last 100): -23.06	Epsilon: 0.2476	Total Steps: 9593Updated target network.
# Episode 99	Average Score (last 100): -23.18	Epsilon: 0.2475	Total Steps: 9693Updated target network.
#
# Saved video for episode 100 to ./rl_renders_agent03_new/episode_000100.mp4
# Episode 100	Average Score (last 100): -22.99	Epsilon: 0.2475	Total Steps: 9793
# Model saved to agent03_new_100k_eps.pth
# Updated target network.
# Episode 101	Average Score (last 100): -20.39	Epsilon: 0.2475	Total Steps: 9893Updated target network.
# Episode 102	Average Score (last 100): -20.39	Epsilon: 0.2475	Total Steps: 9993Updated target network.
# Episode 103	Average Score (last 100): -21.09	Epsilon: 0.2474	Total Steps: 10093Updated target network.
# Episode 104	Average Score (last 100): -20.55	Epsilon: 0.2474	Total Steps: 10193Updated target network.
# Episode 105	Average Score (last 100): -20.26	Epsilon: 0.2474	Total Steps: 10293Updated target network.
# Episode 106	Average Score (last 100): -20.07	Epsilon: 0.2474	Total Steps: 10393Updated target network.
# Episode 107	Average Score (last 100): -19.69	Epsilon: 0.2473	Total Steps: 10493Updated target network.
# Episode 108	Average Score (last 100): -19.56	Epsilon: 0.2473	Total Steps: 10593Updated target network.
# Episode 109	Average Score (last 100): -19.85	Epsilon: 0.2473	Total Steps: 10693Updated target network.
# Episode 110	Average Score (last 100): -19.77	Epsilon: 0.2473	Total Steps: 10793Updated target network.
# Episode 111	Average Score (last 100): -20.10	Epsilon: 0.2472	Total Steps: 10893Updated target network.
# Episode 112	Average Score (last 100): -20.40	Epsilon: 0.2472	Total Steps: 10993Updated target network.
# Episode 113	Average Score (last 100): -21.10	Epsilon: 0.2472	Total Steps: 11093Updated target network.
# Episode 114	Average Score (last 100): -21.58	Epsilon: 0.2472	Total Steps: 11193Updated target network.
# Episode 115	Average Score (last 100): -19.33	Epsilon: 0.2471	Total Steps: 11293Updated target network.
# Episode 116	Average Score (last 100): -19.03	Epsilon: 0.2471	Total Steps: 11393Updated target network.
# Episode 117	Average Score (last 100): -18.83	Epsilon: 0.2471	Total Steps: 11493Updated target network.
# Episode 118	Average Score (last 100): -18.45	Epsilon: 0.2471	Total Steps: 11593Updated target network.
# Episode 119	Average Score (last 100): -18.36	Epsilon: 0.2470	Total Steps: 11693Updated target network.
# Episode 120	Average Score (last 100): -17.77	Epsilon: 0.2470	Total Steps: 11793Updated target network.
# Episode 121	Average Score (last 100): -17.67	Epsilon: 0.2470	Total Steps: 11893Updated target network.
# Episode 122	Average Score (last 100): -17.53	Epsilon: 0.2470	Total Steps: 11993Updated target network.
# Episode 123	Average Score (last 100): -17.61	Epsilon: 0.2469	Total Steps: 12093Updated target network.
# Episode 124	Average Score (last 100): -17.16	Epsilon: 0.2469	Total Steps: 12193Updated target network.
# Episode 125	Average Score (last 100): -16.65	Epsilon: 0.2469	Total Steps: 12293Updated target network.
# Episode 126	Average Score (last 100): -16.86	Epsilon: 0.2469	Total Steps: 12393Updated target network.
# Episode 127	Average Score (last 100): -17.04	Epsilon: 0.2468	Total Steps: 12493Updated target network.
# Episode 128	Average Score (last 100): -16.43	Epsilon: 0.2468	Total Steps: 12593Updated target network.
# Episode 129	Average Score (last 100): -16.15	Epsilon: 0.2468	Total Steps: 12693Updated target network.
# Episode 130	Average Score (last 100): -16.28	Epsilon: 0.2468	Total Steps: 12793Updated target network.
# Episode 131	Average Score (last 100): -16.16	Epsilon: 0.2467	Total Steps: 12893Updated target network.
# Episode 132	Average Score (last 100): -16.41	Epsilon: 0.2467	Total Steps: 12993Updated target network.
# Episode 133	Average Score (last 100): -16.62	Epsilon: 0.2467	Total Steps: 13093Updated target network.
# Episode 134	Average Score (last 100): -16.43	Epsilon: 0.2467	Total Steps: 13193Updated target network.
# Episode 135	Average Score (last 100): -16.45	Epsilon: 0.2466	Total Steps: 13293Updated target network.
# Episode 136	Average Score (last 100): -16.35	Epsilon: 0.2466	Total Steps: 13393Updated target network.
# Episode 137	Average Score (last 100): -16.19	Epsilon: 0.2466	Total Steps: 13493Updated target network.
# Episode 138	Average Score (last 100): -16.24	Epsilon: 0.2466	Total Steps: 13593Updated target network.
# Episode 139	Average Score (last 100): -16.29	Epsilon: 0.2465	Total Steps: 13693Updated target network.
# Episode 140	Average Score (last 100): -15.71	Epsilon: 0.2465	Total Steps: 13793Updated target network.
# Episode 141	Average Score (last 100): -15.52	Epsilon: 0.2465	Total Steps: 13893Updated target network.
# Episode 142	Average Score (last 100): -15.47	Epsilon: 0.2465	Total Steps: 13993Updated target network.
# Episode 143	Average Score (last 100): -15.29	Epsilon: 0.2465	Total Steps: 14093Updated target network.
# Episode 144	Average Score (last 100): -15.57	Epsilon: 0.2464	Total Steps: 14193Updated target network.
# Episode 145	Average Score (last 100): -15.59	Epsilon: 0.2464	Total Steps: 14293Updated target network.
# Episode 146	Average Score (last 100): -15.80	Epsilon: 0.2464	Total Steps: 14393Updated target network.
# Episode 147	Average Score (last 100): -15.79	Epsilon: 0.2464	Total Steps: 14493Updated target network.
# Episode 148	Average Score (last 100): -15.04	Epsilon: 0.2463	Total Steps: 14593Updated target network.
# Episode 149	Average Score (last 100): -14.95	Epsilon: 0.2463	Total Steps: 14693Updated target network.
# Episode 150	Average Score (last 100): -14.74	Epsilon: 0.2463	Total Steps: 14793Updated target network.
# Episode 151	Average Score (last 100): -14.67	Epsilon: 0.2463	Total Steps: 14893Updated target network.
# Episode 152	Average Score (last 100): -15.59	Epsilon: 0.2462	Total Steps: 14993Updated target network.
# Episode 153	Average Score (last 100): -15.40	Epsilon: 0.2462	Total Steps: 15093Updated target network.
# Episode 154	Average Score (last 100): -15.51	Epsilon: 0.2462	Total Steps: 15193Updated target network.
# Episode 155	Average Score (last 100): -15.49	Epsilon: 0.2462	Total Steps: 15293Updated target network.
# Episode 156	Average Score (last 100): -14.78	Epsilon: 0.2461	Total Steps: 15393Updated target network.
# Episode 157	Average Score (last 100): -14.63	Epsilon: 0.2461	Total Steps: 15493Updated target network.
# Episode 158	Average Score (last 100): -14.04	Epsilon: 0.2461	Total Steps: 15593Updated target network.
# Episode 159	Average Score (last 100): -13.95	Epsilon: 0.2461	Total Steps: 15693Updated target network.
# Episode 160	Average Score (last 100): -13.47	Epsilon: 0.2460	Total Steps: 15793Updated target network.
# Episode 161	Average Score (last 100): -13.61	Epsilon: 0.2460	Total Steps: 15893Updated target network.
# Episode 162	Average Score (last 100): -13.61	Epsilon: 0.2460	Total Steps: 15993Updated target network.
# Episode 163	Average Score (last 100): -14.25	Epsilon: 0.2460	Total Steps: 16093Updated target network.
# Episode 164	Average Score (last 100): -13.95	Epsilon: 0.2459	Total Steps: 16193Updated target network.
# Episode 165	Average Score (last 100): -13.66	Epsilon: 0.2459	Total Steps: 16293Updated target network.
# Episode 166	Average Score (last 100): -13.35	Epsilon: 0.2459	Total Steps: 16393Updated target network.
# Episode 167	Average Score (last 100): -12.93	Epsilon: 0.2459	Total Steps: 16493Updated target network.
# Episode 168	Average Score (last 100): -12.79	Epsilon: 0.2458	Total Steps: 16593Updated target network.
# Episode 169	Average Score (last 100): -12.48	Epsilon: 0.2458	Total Steps: 16693Updated target network.
# Episode 170	Average Score (last 100): -12.17	Epsilon: 0.2458	Total Steps: 16793Updated target network.
# Episode 171	Average Score (last 100): -11.77	Epsilon: 0.2458	Total Steps: 16893Updated target network.
# Episode 172	Average Score (last 100): -11.58	Epsilon: 0.2457	Total Steps: 16993Updated target network.
# Episode 173	Average Score (last 100): -11.33	Epsilon: 0.2457	Total Steps: 17093Updated target network.
# Episode 174	Average Score (last 100): -10.92	Epsilon: 0.2457	Total Steps: 17193Updated target network.
# Episode 175	Average Score (last 100): -10.61	Epsilon: 0.2457	Total Steps: 17293Updated target network.
# Episode 176	Average Score (last 100): -11.62	Epsilon: 0.2456	Total Steps: 17393Updated target network.
# Episode 177	Average Score (last 100): -11.56	Epsilon: 0.2456	Total Steps: 17493Updated target network.
# Episode 178	Average Score (last 100): -11.55	Epsilon: 0.2456	Total Steps: 17593Updated target network.
# Episode 179	Average Score (last 100): -11.04	Epsilon: 0.2456	Total Steps: 17693Updated target network.
# Episode 180	Average Score (last 100): -11.10	Epsilon: 0.2455	Total Steps: 17793Updated target network.
# Episode 181	Average Score (last 100): -10.85	Epsilon: 0.2455	Total Steps: 17893Updated target network.
# Episode 182	Average Score (last 100): -10.59	Epsilon: 0.2455	Total Steps: 17993Updated target network.
# Episode 183	Average Score (last 100): -9.88	Epsilon: 0.2455	Total Steps: 18093Updated target network.
# Episode 184	Average Score (last 100): -10.04	Epsilon: 0.2454	Total Steps: 18193Updated target network.
# Episode 185	Average Score (last 100): -9.53	Epsilon: 0.2454	Total Steps: 18293Updated target network.
# Episode 186	Average Score (last 100): -9.32	Epsilon: 0.2454	Total Steps: 18393Updated target network.
# Episode 187	Average Score (last 100): -9.48	Epsilon: 0.2454	Total Steps: 18493Updated target network.
# Episode 188	Average Score (last 100): -9.19	Epsilon: 0.2453	Total Steps: 18593Updated target network.
# Episode 189	Average Score (last 100): -9.00	Epsilon: 0.2453	Total Steps: 18693Updated target network.
# Episode 190	Average Score (last 100): -8.97	Epsilon: 0.2453	Total Steps: 18793Updated target network.
# Episode 191	Average Score (last 100): -9.09	Epsilon: 0.2453	Total Steps: 18893Updated target network.
# Episode 192	Average Score (last 100): -9.19	Epsilon: 0.2452	Total Steps: 18993Updated target network.
# Episode 193	Average Score (last 100): -9.19	Epsilon: 0.2452	Total Steps: 19083Updated target network.
# Episode 194	Average Score (last 100): -9.29	Epsilon: 0.2452	Total Steps: 19183Updated target network.
# Episode 195	Average Score (last 100): -9.39	Epsilon: 0.2452	Total Steps: 19283Updated target network.
# Episode 196	Average Score (last 100): -10.24	Epsilon: 0.2451	Total Steps: 19383Updated target network.
# Episode 197	Average Score (last 100): -10.30	Epsilon: 0.2451	Total Steps: 19483Updated target network.
# Episode 198	Average Score (last 100): -10.30	Epsilon: 0.2451	Total Steps: 19583Updated target network.
# Episode 199	Average Score (last 100): -10.56	Epsilon: 0.2451	Total Steps: 19683Updated target network.
#
# Saved video for episode 200 to ./rl_renders_agent03_new/episode_000200.mp4
# Episode 200	Average Score (last 100): -10.33	Epsilon: 0.2450	Total Steps: 19783
# Model saved to agent03_new_100k_eps.pth
# Updated target network.
# Episode 201	Average Score (last 100): -10.34	Epsilon: 0.2450	Total Steps: 19883Updated target network.
# Episode 202	Average Score (last 100): -10.35	Epsilon: 0.2450	Total Steps: 19983Updated target network.
# Episode 203	Average Score (last 100): -9.82	Epsilon: 0.2450	Total Steps: 20081Updated target network.
# Episode 204	Average Score (last 100): -9.47	Epsilon: 0.2450	Total Steps: 20181Updated target network.
# Episode 205	Average Score (last 100): -9.39	Epsilon: 0.2449	Total Steps: 20281Updated target network.
# Episode 206	Average Score (last 100): -9.49	Epsilon: 0.2449	Total Steps: 20381Updated target network.
# Episode 207	Average Score (last 100): -9.86	Epsilon: 0.2449	Total Steps: 20481Updated target network.
# Episode 208	Average Score (last 100): -10.00	Epsilon: 0.2449	Total Steps: 20581Updated target network.
# Episode 209	Average Score (last 100): -9.81	Epsilon: 0.2448	Total Steps: 20681Updated target network.
# Episode 210	Average Score (last 100): -9.80	Epsilon: 0.2448	Total Steps: 20781Updated target network.
# Episode 211	Average Score (last 100): -9.69	Epsilon: 0.2448	Total Steps: 20881Updated target network.
# Episode 212	Average Score (last 100): -9.16	Epsilon: 0.2448	Total Steps: 20981Updated target network.
# Episode 213	Average Score (last 100): -8.46	Epsilon: 0.2447	Total Steps: 21081Updated target network.
# Episode 214	Average Score (last 100): -7.96	Epsilon: 0.2447	Total Steps: 21181Updated target network.
# Episode 215	Average Score (last 100): -8.06	Epsilon: 0.2447	Total Steps: 21281Updated target network.
# Episode 216	Average Score (last 100): -8.15	Epsilon: 0.2447	Total Steps: 21381Updated target network.
# Episode 217	Average Score (last 100): -8.38	Epsilon: 0.2446	Total Steps: 21481Updated target network.
# Episode 218	Average Score (last 100): -8.68	Epsilon: 0.2446	Total Steps: 21581Updated target network.
# Episode 219	Average Score (last 100): -8.37	Epsilon: 0.2446	Total Steps: 21681Updated target network.
# Episode 220	Average Score (last 100): -8.04	Epsilon: 0.2446	Total Steps: 21781Updated target network.
# Episode 221	Average Score (last 100): -7.88	Epsilon: 0.2445	Total Steps: 21881Updated target network.
# Episode 222	Average Score (last 100): -7.83	Epsilon: 0.2445	Total Steps: 21981Updated target network.
# Episode 223	Average Score (last 100): -7.81	Epsilon: 0.2445	Total Steps: 22081Updated target network.
# Episode 224	Average Score (last 100): -7.85	Epsilon: 0.2445	Total Steps: 22181Updated target network.
# Episode 225	Average Score (last 100): -7.95	Epsilon: 0.2444	Total Steps: 22281Updated target network.
# Episode 226	Average Score (last 100): -8.13	Epsilon: 0.2444	Total Steps: 22381Updated target network.
# Episode 227	Average Score (last 100): -8.05	Epsilon: 0.2444	Total Steps: 22481Updated target network.
# Episode 228	Average Score (last 100): -7.88	Epsilon: 0.2444	Total Steps: 22581Updated target network.
# Episode 229	Average Score (last 100): -8.39	Epsilon: 0.2443	Total Steps: 22681Updated target network.
# Episode 230	Average Score (last 100): -8.26	Epsilon: 0.2443	Total Steps: 22781Updated target network.
# Episode 231	Average Score (last 100): -8.29	Epsilon: 0.2443	Total Steps: 22881Updated target network.
# Episode 232	Average Score (last 100): -7.92	Epsilon: 0.2443	Total Steps: 22981Updated target network.
# Episode 233	Average Score (last 100): -7.91	Epsilon: 0.2442	Total Steps: 23081Updated target network.
# Episode 234	Average Score (last 100): -7.94	Epsilon: 0.2442	Total Steps: 23181Updated target network.
# Episode 235	Average Score (last 100): -8.04	Epsilon: 0.2442	Total Steps: 23281Updated target network.
# Episode 236	Average Score (last 100): -7.95	Epsilon: 0.2442	Total Steps: 23381Updated target network.
# Episode 237	Average Score (last 100): -7.93	Epsilon: 0.2441	Total Steps: 23481Updated target network.
# Episode 238	Average Score (last 100): -7.88	Epsilon: 0.2441	Total Steps: 23581Updated target network.
# Episode 239	Average Score (last 100): -7.97	Epsilon: 0.2441	Total Steps: 23681Updated target network.
# Episode 240	Average Score (last 100): -8.41	Epsilon: 0.2441	Total Steps: 23781Updated target network.
# Episode 241	Average Score (last 100): -8.54	Epsilon: 0.2440	Total Steps: 23881Updated target network.
# Episode 242	Average Score (last 100): -8.66	Epsilon: 0.2440	Total Steps: 23981Updated target network.
# Episode 243	Average Score (last 100): -8.56	Epsilon: 0.2440	Total Steps: 24081Updated target network.
# Episode 244	Average Score (last 100): -8.19	Epsilon: 0.2440	Total Steps: 24181Updated target network.
# Episode 245	Average Score (last 100): -8.19	Epsilon: 0.2439	Total Steps: 24281Updated target network.
# Episode 246	Average Score (last 100): -8.51	Epsilon: 0.2439	Total Steps: 24381Updated target network.
# Episode 247	Average Score (last 100): -8.55	Epsilon: 0.2439	Total Steps: 24481Updated target network.
# Episode 248	Average Score (last 100): -8.86	Epsilon: 0.2439	Total Steps: 24581Updated target network.
# Episode 249	Average Score (last 100): -8.98	Epsilon: 0.2439	Total Steps: 24681Updated target network.
# Episode 250	Average Score (last 100): -9.07	Epsilon: 0.2438	Total Steps: 24781Updated target network.
# Episode 251	Average Score (last 100): -9.23	Epsilon: 0.2438	Total Steps: 24881Updated target network.
# Episode 252	Average Score (last 100): -9.33	Epsilon: 0.2438	Total Steps: 24981Updated target network.
# Episode 253	Average Score (last 100): -9.37	Epsilon: 0.2438	Total Steps: 25081Updated target network.
# Episode 254	Average Score (last 100): -9.45	Epsilon: 0.2437	Total Steps: 25181Updated target network.
# Episode 255	Average Score (last 100): -9.56	Epsilon: 0.2437	Total Steps: 25281Updated target network.
# Episode 256	Average Score (last 100): -10.32	Epsilon: 0.2437	Total Steps: 25375Updated target network.
# Episode 257	Average Score (last 100): -9.91	Epsilon: 0.2437	Total Steps: 25475Updated target network.
# Episode 258	Average Score (last 100): -10.32	Epsilon: 0.2436	Total Steps: 25575Updated target network.
# Episode 259	Average Score (last 100): -10.11	Epsilon: 0.2436	Total Steps: 25675Updated target network.
# Episode 260	Average Score (last 100): -10.61	Epsilon: 0.2436	Total Steps: 25775Updated target network.
# Episode 261	Average Score (last 100): -10.49	Epsilon: 0.2436	Total Steps: 25875Updated target network.
# Episode 262	Average Score (last 100): -10.38	Epsilon: 0.2435	Total Steps: 25975Updated target network.
# Episode 263	Average Score (last 100): -9.85	Epsilon: 0.2435	Total Steps: 26075Updated target network.
# Episode 264	Average Score (last 100): -10.00	Epsilon: 0.2435	Total Steps: 26175Updated target network.
# Episode 265	Average Score (last 100): -10.21	Epsilon: 0.2435	Total Steps: 26275Updated target network.
# Episode 266	Average Score (last 100): -10.40	Epsilon: 0.2434	Total Steps: 26375Updated target network.
# Episode 267	Average Score (last 100): -10.90	Epsilon: 0.2434	Total Steps: 26475Updated target network.
# Episode 268	Average Score (last 100): -11.00	Epsilon: 0.2434	Total Steps: 26575Updated target network.
# Episode 269	Average Score (last 100): -10.79	Epsilon: 0.2434	Total Steps: 26675Updated target network.
# Episode 270	Average Score (last 100): -10.77	Epsilon: 0.2433	Total Steps: 26775Updated target network.
# Episode 271	Average Score (last 100): -10.89	Epsilon: 0.2433	Total Steps: 26875Updated target network.
# Episode 272	Average Score (last 100): -11.14	Epsilon: 0.2433	Total Steps: 26975Updated target network.
# Episode 273	Average Score (last 100): -11.52	Epsilon: 0.2433	Total Steps: 27075Updated target network.
# Episode 274	Average Score (last 100): -11.66	Epsilon: 0.2432	Total Steps: 27175Updated target network.
# Episode 275	Average Score (last 100): -11.95	Epsilon: 0.2432	Total Steps: 27275Updated target network.
# Episode 276	Average Score (last 100): -12.18	Epsilon: 0.2432	Total Steps: 27360Updated target network.
# Episode 277	Average Score (last 100): -12.27	Epsilon: 0.2432	Total Steps: 27460Updated target network.
# Episode 278	Average Score (last 100): -12.38	Epsilon: 0.2431	Total Steps: 27560Updated target network.
# Episode 279	Average Score (last 100): -12.49	Epsilon: 0.2431	Total Steps: 27660Updated target network.
# Episode 280	Average Score (last 100): -12.84	Epsilon: 0.2431	Total Steps: 27760Updated target network.
# Episode 281	Average Score (last 100): -13.12	Epsilon: 0.2431	Total Steps: 27860Updated target network.
# Episode 282	Average Score (last 100): -13.63	Epsilon: 0.2430	Total Steps: 27960Updated target network.
# Episode 283	Average Score (last 100): -13.90	Epsilon: 0.2430	Total Steps: 28060Updated target network.
# Episode 284	Average Score (last 100): -13.57	Epsilon: 0.2430	Total Steps: 28160Updated target network.
# Episode 285	Average Score (last 100): -13.76	Epsilon: 0.2430	Total Steps: 28260Updated target network.
# Episode 286	Average Score (last 100): -13.69	Epsilon: 0.2430	Total Steps: 28360Updated target network.
# Episode 287	Average Score (last 100): -13.63	Epsilon: 0.2429	Total Steps: 28460Updated target network.
# Episode 288	Average Score (last 100): -13.99	Epsilon: 0.2429	Total Steps: 28560Updated target network.
# Episode 289	Average Score (last 100): -14.45	Epsilon: 0.2429	Total Steps: 28660Updated target network.
# Episode 290	Average Score (last 100): -14.29	Epsilon: 0.2429	Total Steps: 28760Updated target network.
# Episode 291	Average Score (last 100): -14.84	Epsilon: 0.2428	Total Steps: 28860Updated target network.
# Episode 292	Average Score (last 100): -14.27	Epsilon: 0.2428	Total Steps: 28960Updated target network.
# Episode 293	Average Score (last 100): -14.32	Epsilon: 0.2428	Total Steps: 29060Updated target network.
# Episode 294	Average Score (last 100): -14.36	Epsilon: 0.2428	Total Steps: 29160Updated target network.
# Episode 295	Average Score (last 100): -14.35	Epsilon: 0.2427	Total Steps: 29260Updated target network.
# Episode 296	Average Score (last 100): -13.64	Epsilon: 0.2427	Total Steps: 29360Updated target network.
# Episode 297	Average Score (last 100): -13.45	Epsilon: 0.2427	Total Steps: 29460Updated target network.
# Episode 298	Average Score (last 100): -13.25	Epsilon: 0.2427	Total Steps: 29560Updated target network.
# Episode 299	Average Score (last 100): -12.76	Epsilon: 0.2426	Total Steps: 29660Updated target network.
#
# Saved video for episode 300 to ./rl_renders_agent03_new/episode_000300.mp4
# Episode 300	Average Score (last 100): -13.25	Epsilon: 0.2426	Total Steps: 29760
# Model saved to agent03_new_100k_eps.pth
# Updated target network.
# Episode 301	Average Score (last 100): -13.39	Epsilon: 0.2426	Total Steps: 29860Updated target network.
# Episode 302	Average Score (last 100): -13.40	Epsilon: 0.2426	Total Steps: 29960Updated target network.
# Episode 303	Average Score (last 100): -13.58	Epsilon: 0.2425	Total Steps: 30060Updated target network.
# Episode 304	Average Score (last 100): -13.87	Epsilon: 0.2425	Total Steps: 30160Updated target network.
# Episode 305	Average Score (last 100): -13.95	Epsilon: 0.2425	Total Steps: 30260Updated target network.
# Episode 306	Average Score (last 100): -14.25	Epsilon: 0.2425	Total Steps: 30360Updated target network.
# Episode 307	Average Score (last 100): -13.96	Epsilon: 0.2424	Total Steps: 30460Updated target network.
# Episode 308	Average Score (last 100): -13.44	Epsilon: 0.2424	Total Steps: 30560Updated target network.
# Episode 309	Average Score (last 100): -13.53	Epsilon: 0.2424	Total Steps: 30660Updated target network.
# Episode 310	Average Score (last 100): -13.42	Epsilon: 0.2424	Total Steps: 30760Updated target network.
# Episode 311	Average Score (last 100): -13.52	Epsilon: 0.2423	Total Steps: 30860Updated target network.
# Episode 312	Average Score (last 100): -13.54	Epsilon: 0.2423	Total Steps: 30960Updated target network.
# Episode 313	Average Score (last 100): -13.44	Epsilon: 0.2423	Total Steps: 31060Updated target network.
# Episode 314	Average Score (last 100): -13.04	Epsilon: 0.2423	Total Steps: 31160Updated target network.
# Episode 315	Average Score (last 100): -12.45	Epsilon: 0.2422	Total Steps: 31260Updated target network.
# Episode 316	Average Score (last 100): -12.22	Epsilon: 0.2422	Total Steps: 31360Updated target network.
# Episode 317	Average Score (last 100): -11.90	Epsilon: 0.2422	Total Steps: 31460Updated target network.
# Episode 318	Average Score (last 100): -11.49	Epsilon: 0.2422	Total Steps: 31560Updated target network.
# Episode 319	Average Score (last 100): -11.50	Epsilon: 0.2422	Total Steps: 31660Updated target network.
# Episode 320	Average Score (last 100): -12.01	Epsilon: 0.2421	Total Steps: 31760Updated target network.
# Episode 321	Average Score (last 100): -12.08	Epsilon: 0.2421	Total Steps: 31860Updated target network.
# Episode 322	Average Score (last 100): -12.14	Epsilon: 0.2421	Total Steps: 31960Updated target network.
# Episode 323	Average Score (last 100): -12.37	Epsilon: 0.2421	Total Steps: 32060Updated target network.
# Episode 324	Average Score (last 100): -11.60	Epsilon: 0.2420	Total Steps: 32160Updated target network.
# Episode 325	Average Score (last 100): -11.40	Epsilon: 0.2420	Total Steps: 32260Updated target network.
# Episode 326	Average Score (last 100): -11.12	Epsilon: 0.2420	Total Steps: 32360Updated target network.
# Episode 327	Average Score (last 100): -10.94	Epsilon: 0.2420	Total Steps: 32460Updated target network.
# Episode 328	Average Score (last 100): -11.66	Epsilon: 0.2419	Total Steps: 32560Updated target network.
# Episode 329	Average Score (last 100): -11.24	Epsilon: 0.2419	Total Steps: 32660Updated target network.
# Episode 330	Average Score (last 100): -11.26	Epsilon: 0.2419	Total Steps: 32760Updated target network.
# Episode 331	Average Score (last 100): -11.58	Epsilon: 0.2419	Total Steps: 32860Updated target network.
# Episode 332	Average Score (last 100): -12.79	Epsilon: 0.2418	Total Steps: 32960Updated target network.
# Episode 333	Average Score (last 100): -12.88	Epsilon: 0.2418	Total Steps: 33060Updated target network.
# Episode 334	Average Score (last 100): -12.54	Epsilon: 0.2418	Total Steps: 33160Updated target network.
# Episode 335	Average Score (last 100): -12.24	Epsilon: 0.2418	Total Steps: 33260Updated target network.
# Episode 336	Average Score (last 100): -12.17	Epsilon: 0.2417	Total Steps: 33360Updated target network.
# Episode 337	Average Score (last 100): -12.15	Epsilon: 0.2417	Total Steps: 33460Updated target network.
# Episode 338	Average Score (last 100): -12.64	Epsilon: 0.2417	Total Steps: 33560Updated target network.
# Episode 339	Average Score (last 100): -12.66	Epsilon: 0.2417	Total Steps: 33660Updated target network.
# Episode 340	Average Score (last 100): -11.69	Epsilon: 0.2416	Total Steps: 33760Updated target network.
# Episode 341	Average Score (last 100): -11.22	Epsilon: 0.2416	Total Steps: 33860Updated target network.
# Episode 342	Average Score (last 100): -11.23	Epsilon: 0.2416	Total Steps: 33960Updated target network.
# Episode 343	Average Score (last 100): -11.46	Epsilon: 0.2416	Total Steps: 34060Updated target network.
# Episode 344	Average Score (last 100): -11.87	Epsilon: 0.2415	Total Steps: 34160Updated target network.
# Episode 345	Average Score (last 100): -11.86	Epsilon: 0.2415	Total Steps: 34260Updated target network.
# Episode 346	Average Score (last 100): -11.56	Epsilon: 0.2415	Total Steps: 34360Updated target network.
# Episode 347	Average Score (last 100): -11.31	Epsilon: 0.2415	Total Steps: 34448Updated target network.
# Episode 348	Average Score (last 100): -11.83	Epsilon: 0.2414	Total Steps: 34519Updated target network.
# Episode 349	Average Score (last 100): -12.02	Epsilon: 0.2414	Total Steps: 34619Updated target network.
# Episode 350	Average Score (last 100): -12.04	Epsilon: 0.2414	Total Steps: 34719Updated target network.
# Episode 351	Average Score (last 100): -12.44	Epsilon: 0.2414	Total Steps: 34819Updated target network.
# Episode 352	Average Score (last 100): -11.31	Epsilon: 0.2414	Total Steps: 34919Updated target network.
# Episode 353	Average Score (last 100): -11.07	Epsilon: 0.2413	Total Steps: 35019Updated target network.
# Episode 354	Average Score (last 100): -10.93	Epsilon: 0.2413	Total Steps: 35119Updated target network.
# Episode 355	Average Score (last 100): -10.73	Epsilon: 0.2413	Total Steps: 35219Updated target network.
# Episode 356	Average Score (last 100): -9.66	Epsilon: 0.2413	Total Steps: 35319Updated target network.
# Episode 357	Average Score (last 100): -9.87	Epsilon: 0.2412	Total Steps: 35419Updated target network.
# Episode 358	Average Score (last 100): -9.85	Epsilon: 0.2412	Total Steps: 35519Updated target network.
# Episode 359	Average Score (last 100): -10.14	Epsilon: 0.2412	Total Steps: 35619Updated target network.
# Episode 360	Average Score (last 100): -9.55	Epsilon: 0.2412	Total Steps: 35719Updated target network.
# Episode 361	Average Score (last 100): -10.04	Epsilon: 0.2411	Total Steps: 35819Updated target network.
# Episode 362	Average Score (last 100): -9.95	Epsilon: 0.2411	Total Steps: 35919Updated target network.
# Episode 363	Average Score (last 100): -9.78	Epsilon: 0.2411	Total Steps: 36019Updated target network.
# Episode 364	Average Score (last 100): -10.11	Epsilon: 0.2411	Total Steps: 36119Updated target network.
# Episode 365	Average Score (last 100): -10.10	Epsilon: 0.2410	Total Steps: 36219Updated target network.
# Episode 366	Average Score (last 100): -10.14	Epsilon: 0.2410	Total Steps: 36319Updated target network.
# Episode 367	Average Score (last 100): -10.21	Epsilon: 0.2410	Total Steps: 36419Updated target network.
# Episode 368	Average Score (last 100): -10.07	Epsilon: 0.2410	Total Steps: 36519Updated target network.
# Episode 369	Average Score (last 100): -10.40	Epsilon: 0.2409	Total Steps: 36619Updated target network.
# Episode 370	Average Score (last 100): -10.64	Epsilon: 0.2409	Total Steps: 36719Updated target network.
# Episode 372	Average Score (last 100): -10.35	Epsilon: 0.2409	Total Steps: 36890Updated target network.
# Episode 373	Average Score (last 100): -9.86	Epsilon: 0.2408	Total Steps: 36990Updated target network.
# Episode 374	Average Score (last 100): -9.97	Epsilon: 0.2408	Total Steps: 37090Updated target network.
# Episode 375	Average Score (last 100): -9.59	Epsilon: 0.2408	Total Steps: 37190Updated target network.
# Episode 376	Average Score (last 100): -8.79	Epsilon: 0.2408	Total Steps: 37290Updated target network.
# Episode 377	Average Score (last 100): -8.86	Epsilon: 0.2407	Total Steps: 37390Updated target network.
# Episode 378	Average Score (last 100): -8.96	Epsilon: 0.2407	Total Steps: 37490Updated target network.
# Episode 379	Average Score (last 100): -9.28	Epsilon: 0.2407	Total Steps: 37590Updated target network.
# Episode 380	Average Score (last 100): -8.53	Epsilon: 0.2407	Total Steps: 37690Updated target network.
# Episode 381	Average Score (last 100): -8.31	Epsilon: 0.2407	Total Steps: 37790Updated target network.
# Episode 382	Average Score (last 100): -7.88	Epsilon: 0.2406	Total Steps: 37890Updated target network.
# Episode 383	Average Score (last 100): -7.59	Epsilon: 0.2406	Total Steps: 37990Updated target network.
# Episode 384	Average Score (last 100): -7.95	Epsilon: 0.2406	Total Steps: 38090Updated target network.
# Episode 385	Average Score (last 100): -7.85	Epsilon: 0.2406	Total Steps: 38190Updated target network.
# Episode 386	Average Score (last 100): -7.62	Epsilon: 0.2405	Total Steps: 38290Updated target network.
# Episode 387	Average Score (last 100): -7.30	Epsilon: 0.2405	Total Steps: 38390Updated target network.
# Episode 388	Average Score (last 100): -6.82	Epsilon: 0.2405	Total Steps: 38490Updated target network.
# Episode 389	Average Score (last 100): -6.35	Epsilon: 0.2405	Total Steps: 38590Updated target network.
# Episode 390	Average Score (last 100): -6.73	Epsilon: 0.2404	Total Steps: 38690Updated target network.
# Episode 391	Average Score (last 100): -6.59	Epsilon: 0.2404	Total Steps: 38790Updated target network.
# Episode 392	Average Score (last 100): -6.60	Epsilon: 0.2404	Total Steps: 38890Updated target network.
# Episode 393	Average Score (last 100): -6.66	Epsilon: 0.2404	Total Steps: 38990Updated target network.
# Episode 394	Average Score (last 100): -7.02	Epsilon: 0.2403	Total Steps: 39090Updated target network.
# Episode 395	Average Score (last 100): -7.22	Epsilon: 0.2403	Total Steps: 39190Updated target network.
# Episode 396	Average Score (last 100): -7.83	Epsilon: 0.2403	Total Steps: 39290Updated target network.
# Episode 397	Average Score (last 100): -8.12	Epsilon: 0.2403	Total Steps: 39390Updated target network.
# Episode 398	Average Score (last 100): -8.27	Epsilon: 0.2402	Total Steps: 39490Updated target network.
# Episode 399	Average Score (last 100): -8.36	Epsilon: 0.2402	Total Steps: 39590Updated target network.
#
# Saved video for episode 400 to ./rl_renders_agent03_new/episode_000400.mp4
# Episode 400	Average Score (last 100): -7.77	Epsilon: 0.2402	Total Steps: 39690
# Model saved to agent03_new_100k_eps.pth
# Updated target network.
# Episode 401	Average Score (last 100): -7.51	Epsilon: 0.2402	Total Steps: 39790Updated target network.
# Episode 402	Average Score (last 100): -7.36	Epsilon: 0.2401	Total Steps: 39880Updated target network.
# Episode 403	Average Score (last 100): -7.43	Epsilon: 0.2401	Total Steps: 39980Updated target network.
# Episode 404	Average Score (last 100): -6.99	Epsilon: 0.2401	Total Steps: 40080Updated target network.
# Episode 405	Average Score (last 100): -7.60	Epsilon: 0.2401	Total Steps: 40180Updated target network.
# Episode 406	Average Score (last 100): -7.40	Epsilon: 0.2401	Total Steps: 40280Updated target network.
# Episode 407	Average Score (last 100): -7.60	Epsilon: 0.2400	Total Steps: 40374Updated target network.
# Episode 408	Average Score (last 100): -7.87	Epsilon: 0.2400	Total Steps: 40474Updated target network.
# Episode 409	Average Score (last 100): -7.79	Epsilon: 0.2400	Total Steps: 40574Updated target network.
# Episode 410	Average Score (last 100): -7.69	Epsilon: 0.2400	Total Steps: 40674Updated target network.
# Episode 411	Average Score (last 100): -7.50	Epsilon: 0.2399	Total Steps: 40774Updated target network.
# Episode 412	Average Score (last 100): -7.89	Epsilon: 0.2399	Total Steps: 40874Updated target network.
# Episode 413	Average Score (last 100): -8.13	Epsilon: 0.2399	Total Steps: 40974Updated target network.
# Episode 414	Average Score (last 100): -8.37	Epsilon: 0.2399	Total Steps: 41074Updated target network.
# Episode 415	Average Score (last 100): -8.37	Epsilon: 0.2398	Total Steps: 41174Updated target network.
# Episode 416	Average Score (last 100): -8.91	Epsilon: 0.2398	Total Steps: 41274Updated target network.
# Episode 417	Average Score (last 100): -9.11	Epsilon: 0.2398	Total Steps: 41374Updated target network.
# Episode 418	Average Score (last 100): -9.21	Epsilon: 0.2398	Total Steps: 41474Updated target network.
# Episode 419	Average Score (last 100): -9.31	Epsilon: 0.2397	Total Steps: 41574Updated target network.
# Episode 420	Average Score (last 100): -9.49	Epsilon: 0.2397	Total Steps: 41626Updated target network.
# Episode 421	Average Score (last 100): -9.40	Epsilon: 0.2397	Total Steps: 41726Updated target network.
# Episode 422	Average Score (last 100): -9.33	Epsilon: 0.2397	Total Steps: 41826Updated target network.
# Episode 423	Average Score (last 100): -9.34	Epsilon: 0.2396	Total Steps: 41926Updated target network.
# Episode 424	Average Score (last 100): -9.72	Epsilon: 0.2396	Total Steps: 42014Updated target network.
# Episode 425	Average Score (last 100): -9.71	Epsilon: 0.2396	Total Steps: 42114Updated target network.
# Episode 426	Average Score (last 100): -10.25	Epsilon: 0.2396	Total Steps: 42214Updated target network.
# Episode 427	Average Score (last 100): -10.33	Epsilon: 0.2395	Total Steps: 42314Updated target network.
# Episode 428	Average Score (last 100): -9.79	Epsilon: 0.2395	Total Steps: 42414Updated target network.
# Episode 429	Average Score (last 100): -9.81	Epsilon: 0.2395	Total Steps: 42514Updated target network.
# Episode 430	Average Score (last 100): -9.89	Epsilon: 0.2395	Total Steps: 42614Updated target network.
# Episode 431	Average Score (last 100): -9.84	Epsilon: 0.2395	Total Steps: 42714Updated target network.
# Episode 432	Average Score (last 100): -8.50	Epsilon: 0.2394	Total Steps: 42814Updated target network.
# Episode 433	Average Score (last 100): -8.51	Epsilon: 0.2394	Total Steps: 42914Updated target network.
# Episode 434	Average Score (last 100): -8.62	Epsilon: 0.2394	Total Steps: 43014Updated target network.
# Episode 435	Average Score (last 100): -8.61	Epsilon: 0.2394	Total Steps: 43114Updated target network.
# Episode 436	Average Score (last 100): -9.39	Epsilon: 0.2393	Total Steps: 43214Updated target network.
# Episode 437	Average Score (last 100): -9.71	Epsilon: 0.2393	Total Steps: 43314Updated target network.
# Episode 438	Average Score (last 100): -9.52	Epsilon: 0.2393	Total Steps: 43414Updated target network.
# Episode 439	Average Score (last 100): -9.41	Epsilon: 0.2393	Total Steps: 43514Updated target network.
# Episode 440	Average Score (last 100): -10.00	Epsilon: 0.2392	Total Steps: 43614Updated target network.
# Episode 441	Average Score (last 100): -10.07	Epsilon: 0.2392	Total Steps: 43714Updated target network.
# Episode 442	Average Score (last 100): -10.15	Epsilon: 0.2392	Total Steps: 43814Updated target network.
# Episode 444	Average Score (last 100): -10.20	Epsilon: 0.2391	Total Steps: 43998Updated target network.
# Episode 445	Average Score (last 100): -10.24	Epsilon: 0.2391	Total Steps: 44098Updated target network.
# Episode 446	Average Score (last 100): -9.97	Epsilon: 0.2391	Total Steps: 44198Updated target network.
# Episode 447	Average Score (last 100): -9.91	Epsilon: 0.2391	Total Steps: 44298Updated target network.
# Episode 448	Average Score (last 100): -9.74	Epsilon: 0.2390	Total Steps: 44398Updated target network.
# Episode 449	Average Score (last 100): -9.44	Epsilon: 0.2390	Total Steps: 44498Updated target network.
# Episode 450	Average Score (last 100): -9.24	Epsilon: 0.2390	Total Steps: 44598Updated target network.
# Episode 451	Average Score (last 100): -9.22	Epsilon: 0.2390	Total Steps: 44698Updated target network.
# Episode 452	Average Score (last 100): -8.90	Epsilon: 0.2390	Total Steps: 44798Updated target network.
# Episode 453	Average Score (last 100): -9.40	Epsilon: 0.2389	Total Steps: 44898Updated target network.
# Episode 454	Average Score (last 100): -9.72	Epsilon: 0.2389	Total Steps: 44998Updated target network.
# Episode 455	Average Score (last 100): -9.93	Epsilon: 0.2389	Total Steps: 45098Updated target network.
# Episode 456	Average Score (last 100): -10.66	Epsilon: 0.2389	Total Steps: 45198Updated target network.
# Episode 457	Average Score (last 100): -10.41	Epsilon: 0.2388	Total Steps: 45298Updated target network.
# Episode 458	Average Score (last 100): -10.21	Epsilon: 0.2388	Total Steps: 45398Updated target network.
# Episode 459	Average Score (last 100): -10.08	Epsilon: 0.2388	Total Steps: 45498Updated target network.
# Episode 460	Average Score (last 100): -10.09	Epsilon: 0.2388	Total Steps: 45598Updated target network.
# Episode 461	Average Score (last 100): -9.59	Epsilon: 0.2387	Total Steps: 45698Updated target network.
# Episode 462	Average Score (last 100): -9.68	Epsilon: 0.2387	Total Steps: 45798Updated target network.
# Episode 463	Average Score (last 100): -9.63	Epsilon: 0.2387	Total Steps: 45898Updated target network.
# Episode 464	Average Score (last 100): -9.36	Epsilon: 0.2387	Total Steps: 45998Updated target network.
# Episode 465	Average Score (last 100): -9.35	Epsilon: 0.2386	Total Steps: 46098Updated target network.
# ...
# Episode 14028	Average Score (last 100): 17.47	Epsilon: 0.0615	Total Steps: 1388310Updated target network.
# Episode 14029	Average Score (last 100): 17.57	Epsilon: 0.0615	Total Steps: 1388410Updated target network.
# Episode 14030	Average Score (last 100): 17.57	Epsilon: 0.0615	Total Steps: 1388510Updated target network.
# Episode 14031	Average Score (last 100): 17.47	Epsilon: 0.0615	Total Steps: 1388610Updated target network.
# Episode 14032	Average Score (last 100): 17.56	Epsilon: 0.0614	Total Steps: 1388710Updated target network.
# Episode 14033	Average Score (last 100): 17.46	Epsilon: 0.0614	Total Steps: 1388810Updated target network.
# Episode 14034	Average Score (last 100): 17.46	Epsilon: 0.0614	Total Steps: 1388910Updated target network.
# Episode 14035	Average Score (last 100): 17.46	Epsilon: 0.0614	Total Steps: 1389010Updated target network.
# Episode 14036	Average Score (last 100): 17.62	Epsilon: 0.0614	Total Steps: 1389110Updated target network.
# Episode 14037	Average Score (last 100): 17.62	Epsilon: 0.0614	Total Steps: 1389210Updated target network.
# Episode 14038	Average Score (last 100): 17.71	Epsilon: 0.0614	Total Steps: 1389310Updated target network.
# Episode 14039	Average Score (last 100): 17.72	Epsilon: 0.0614	Total Steps: 1389410Updated target network.
# Episode 14040	Average Score (last 100): 17.55	Epsilon: 0.0614	Total Steps: 1389510Updated target network.
# Episode 14041	Average Score (last 100): 17.52	Epsilon: 0.0614	Total Steps: 1389610Updated target network.
# Episode 14042	Average Score (last 100): 17.42	Epsilon: 0.0614	Total Steps: 1389710Updated target network.
# Episode 14043	Average Score (last 100): 17.50	Epsilon: 0.0614	Total Steps: 1389810Updated target network.
# Episode 14044	Average Score (last 100): 16.39	Epsilon: 0.0614	Total Steps: 1389910Updated target network.
# Episode 14045	Average Score (last 100): 16.33	Epsilon: 0.0614	Total Steps: 1390010Updated target network.
# Episode 14046	Average Score (last 100): 16.13	Epsilon: 0.0614	Total Steps: 1390110Updated target network.
# Episode 14047	Average Score (last 100): 16.03	Epsilon: 0.0614	Total Steps: 1390210Updated target network.
# Episode 14048	Average Score (last 100): 16.18	Epsilon: 0.0613	Total Steps: 1390310Updated target network.
# Episode 14049	Average Score (last 100): 16.08	Epsilon: 0.0613	Total Steps: 1390410Updated target network.
# Episode 14050	Average Score (last 100): 16.08	Epsilon: 0.0613	Total Steps: 1390510Updated target network.
# Episode 14051	Average Score (last 100): 16.18	Epsilon: 0.0613	Total Steps: 1390610Updated target network.
# Episode 14052	Average Score (last 100): 16.84	Epsilon: 0.0613	Total Steps: 1390710Updated target network.
# Episode 14053	Average Score (last 100): 16.84	Epsilon: 0.0613	Total Steps: 1390810Updated target network.
# Episode 14054	Average Score (last 100): 16.84	Epsilon: 0.0613	Total Steps: 1390910Updated target network.
# Episode 14055	Average Score (last 100): 17.05	Epsilon: 0.0613	Total Steps: 1391010Updated target network.
# Episode 14056	Average Score (last 100): 17.30	Epsilon: 0.0613	Total Steps: 1391110Updated target network.
# Episode 14057	Average Score (last 100): 17.20	Epsilon: 0.0613	Total Steps: 1391210Updated target network.
# Episode 14058	Average Score (last 100): 17.10	Epsilon: 0.0613	Total Steps: 1391310Updated target network.
# Episode 14060	Average Score (last 100): 16.61	Epsilon: 0.0613	Total Steps: 1391436Updated target network.
# Episode 14061	Average Score (last 100): 16.62	Epsilon: 0.0613	Total Steps: 1391536Updated target network.
# Episode 14062	Average Score (last 100): 16.57	Epsilon: 0.0613	Total Steps: 1391636Updated target network.
# Episode 14063	Average Score (last 100): 16.40	Epsilon: 0.0613	Total Steps: 1391736Updated target network.
# Episode 14064	Average Score (last 100): 16.42	Epsilon: 0.0613	Total Steps: 1391836Updated target network.
# Episode 14065	Average Score (last 100): 16.21	Epsilon: 0.0612	Total Steps: 1391936Updated target network.
# Episode 14066	Average Score (last 100): 15.91	Epsilon: 0.0612	Total Steps: 1392036Updated target network.
# Episode 14067	Average Score (last 100): 15.81	Epsilon: 0.0612	Total Steps: 1392136Updated target network.
# Episode 14068	Average Score (last 100): 15.35	Epsilon: 0.0612	Total Steps: 1392236Updated target network.
# Episode 14069	Average Score (last 100): 15.55	Epsilon: 0.0612	Total Steps: 1392336Updated target network.
# Episode 14070	Average Score (last 100): 15.45	Epsilon: 0.0612	Total Steps: 1392436Updated target network.
# Episode 14071	Average Score (last 100): 15.65	Epsilon: 0.0612	Total Steps: 1392536Updated target network.
# Episode 14072	Average Score (last 100): 16.13	Epsilon: 0.0612	Total Steps: 1392636Updated target network.
# Episode 14073	Average Score (last 100): 16.33	Epsilon: 0.0612	Total Steps: 1392736Updated target network.
# Episode 14074	Average Score (last 100): 16.03	Epsilon: 0.0612	Total Steps: 1392836Updated target network.
# Episode 14075	Average Score (last 100): 15.84	Epsilon: 0.0612	Total Steps: 1392936Updated target network.
# Episode 14076	Average Score (last 100): 15.54	Epsilon: 0.0612	Total Steps: 1393036Updated target network.
# Episode 14077	Average Score (last 100): 15.34	Epsilon: 0.0612	Total Steps: 1393107Updated target network.
# Episode 14078	Average Score (last 100): 15.55	Epsilon: 0.0612	Total Steps: 1393207Updated target network.
# Episode 14079	Average Score (last 100): 15.24	Epsilon: 0.0612	Total Steps: 1393307Updated target network.
# Episode 14080	Average Score (last 100): 15.57	Epsilon: 0.0612	Total Steps: 1393407Updated target network.
# Episode 14081	Average Score (last 100): 15.57	Epsilon: 0.0611	Total Steps: 1393507Updated target network.
# Episode 14082	Average Score (last 100): 15.57	Epsilon: 0.0611	Total Steps: 1393607Updated target network.
# Episode 14083	Average Score (last 100): 15.46	Epsilon: 0.0611	Total Steps: 1393707Updated target network.
# Episode 14084	Average Score (last 100): 15.13	Epsilon: 0.0611	Total Steps: 1393807Updated target network.
# Episode 14085	Average Score (last 100): 15.13	Epsilon: 0.0611	Total Steps: 1393907Updated target network.
# Episode 14086	Average Score (last 100): 15.13	Epsilon: 0.0611	Total Steps: 1394007Updated target network.
# Episode 14087	Average Score (last 100): 15.12	Epsilon: 0.0611	Total Steps: 1394107Updated target network.
# Episode 14088	Average Score (last 100): 14.94	Epsilon: 0.0611	Total Steps: 1394207Updated target network.
# Episode 14089	Average Score (last 100): 14.64	Epsilon: 0.0611	Total Steps: 1394307Updated target network.
# Episode 14090	Average Score (last 100): 14.64	Epsilon: 0.0611	Total Steps: 1394407Updated target network.
# Episode 14091	Average Score (last 100): 14.74	Epsilon: 0.0611	Total Steps: 1394507Updated target network.
# Episode 14092	Average Score (last 100): 14.61	Epsilon: 0.0611	Total Steps: 1394607Updated target network.
# Episode 14093	Average Score (last 100): 14.52	Epsilon: 0.0611	Total Steps: 1394707Updated target network.
# Episode 14094	Average Score (last 100): 14.52	Epsilon: 0.0611	Total Steps: 1394807Updated target network.
# Episode 14095	Average Score (last 100): 14.42	Epsilon: 0.0611	Total Steps: 1394907Updated target network.
# Episode 14096	Average Score (last 100): 13.86	Epsilon: 0.0611	Total Steps: 1395007Updated target network.
# Episode 14097	Average Score (last 100): 14.07	Epsilon: 0.0610	Total Steps: 1395107Updated target network.
# Episode 14098	Average Score (last 100): 14.27	Epsilon: 0.0610	Total Steps: 1395207Updated target network.
# Episode 14099	Average Score (last 100): 14.33	Epsilon: 0.0610	Total Steps: 1395307Updated target network.
#
# Saved video for episode 14100 to ./rl_renders_agent03_new/episode_014100.mp4
# Episode 14100	Average Score (last 100): 14.78	Epsilon: 0.0610	Total Steps: 1395407
# Model saved to agent03_new_100k_eps.pth
# Updated target network.
# Episode 14101	Average Score (last 100): 14.88	Epsilon: 0.0610	Total Steps: 1395507Updated target network.
# Episode 14102	Average Score (last 100): 14.78	Epsilon: 0.0610	Total Steps: 1395607Updated target network.
# Episode 14103	Average Score (last 100): 14.88	Epsilon: 0.0610	Total Steps: 1395707Updated target network.
# Episode 14104	Average Score (last 100): 14.88	Epsilon: 0.0610	Total Steps: 1395807Updated target network.
# Episode 14105	Average Score (last 100): 14.78	Epsilon: 0.0610	Total Steps: 1395907Updated target network.
# Episode 14106	Average Score (last 100): 14.88	Epsilon: 0.0610	Total Steps: 1396007Updated target network.
# Episode 14107	Average Score (last 100): 15.00	Epsilon: 0.0610	Total Steps: 1396107Updated target network.
# Episode 14108	Average Score (last 100): 14.44	Epsilon: 0.0610	Total Steps: 1396207Updated target network.
# Episode 14109	Average Score (last 100): 14.54	Epsilon: 0.0610	Total Steps: 1396307Updated target network.
# Episode 14110	Average Score (last 100): 14.44	Epsilon: 0.0610	Total Steps: 1396407Updated target network.
# Episode 14111	Average Score (last 100): 14.56	Epsilon: 0.0610	Total Steps: 1396507Updated target network.
# Episode 14112	Average Score (last 100): 14.15	Epsilon: 0.0610	Total Steps: 1396607Updated target network.
# Episode 14113	Average Score (last 100): 14.05	Epsilon: 0.0610	Total Steps: 1396707Updated target network.
# Episode 14114	Average Score (last 100): 14.15	Epsilon: 0.0609	Total Steps: 1396807Updated target network.
# Episode 14115	Average Score (last 100): 14.04	Epsilon: 0.0609	Total Steps: 1396907Updated target network.
# Episode 14116	Average Score (last 100): 14.03	Epsilon: 0.0609	Total Steps: 1397007Updated target network.
# Episode 14117	Average Score (last 100): 13.95	Epsilon: 0.0609	Total Steps: 1397107Updated target network.
# Episode 14118	Average Score (last 100): 13.62	Epsilon: 0.0609	Total Steps: 1397207Updated target network.
# Episode 14119	Average Score (last 100): 13.72	Epsilon: 0.0609	Total Steps: 1397307Updated target network.
# Episode 14120	Average Score (last 100): 14.19	Epsilon: 0.0609	Total Steps: 1397407Updated target network.
# Episode 14121	Average Score (last 100): 14.19	Epsilon: 0.0609	Total Steps: 1397507Updated target network.
# Episode 14122	Average Score (last 100): 14.29	Epsilon: 0.0609	Total Steps: 1397607Updated target network.
# Episode 14123	Average Score (last 100): 14.47	Epsilon: 0.0609	Total Steps: 1397707Updated target network.
# Episode 14124	Average Score (last 100): 14.29	Epsilon: 0.0609	Total Steps: 1397807Updated target network.
# Episode 14125	Average Score (last 100): 14.19	Epsilon: 0.0609	Total Steps: 1397907Updated target network.
# Episode 14126	Average Score (last 100): 14.13	Epsilon: 0.0609	Total Steps: 1398007Updated target network.
# Episode 14127	Average Score (last 100): 13.90	Epsilon: 0.0609	Total Steps: 1398107Updated target network.
# Episode 14128	Average Score (last 100): 13.10	Epsilon: 0.0609	Total Steps: 1398207Updated target network.
# Episode 14129	Average Score (last 100): 13.10	Epsilon: 0.0609	Total Steps: 1398307Updated target network.
# Episode 14130	Average Score (last 100): 13.10	Epsilon: 0.0608	Total Steps: 1398407Updated target network.
# Episode 14131	Average Score (last 100): 13.10	Epsilon: 0.0608	Total Steps: 1398507Updated target network.
# Episode 14132	Average Score (last 100): 14.29	Epsilon: 0.0608	Total Steps: 1398607Updated target network.
# Episode 14133	Average Score (last 100): 14.50	Epsilon: 0.0608	Total Steps: 1398707Updated target network.
# Episode 14134	Average Score (last 100): 14.49	Epsilon: 0.0608	Total Steps: 1398807Updated target network.
# Episode 14135	Average Score (last 100): 14.49	Epsilon: 0.0608	Total Steps: 1398907Updated target network.
# Episode 14136	Average Score (last 100): 14.22	Epsilon: 0.0608	Total Steps: 1399007Updated target network.
# Episode 14137	Average Score (last 100): 14.22	Epsilon: 0.0608	Total Steps: 1399107Updated target network.
# Episode 14138	Average Score (last 100): 14.23	Epsilon: 0.0608	Total Steps: 1399207Updated target network.
# Episode 14139	Average Score (last 100): 14.13	Epsilon: 0.0608	Total Steps: 1399307Updated target network.
# Episode 14140	Average Score (last 100): 14.68	Epsilon: 0.0608	Total Steps: 1399407Updated target network.
# Episode 14141	Average Score (last 100): 14.51	Epsilon: 0.0608	Total Steps: 1399507Updated target network.
# Episode 14142	Average Score (last 100): 14.61	Epsilon: 0.0608	Total Steps: 1399607Updated target network.
# Episode 14143	Average Score (last 100): 14.63	Epsilon: 0.0608	Total Steps: 1399707Updated target network.
# Episode 14144	Average Score (last 100): 15.39	Epsilon: 0.0608	Total Steps: 1399807Updated target network.
# Episode 14145	Average Score (last 100): 15.36	Epsilon: 0.0608	Total Steps: 1399907Updated target network.
# Episode 14146	Average Score (last 100): 15.56	Epsilon: 0.0608	Total Steps: 1400007Updated target network.
# Episode 14147	Average Score (last 100): 15.66	Epsilon: 0.0607	Total Steps: 1400107Updated target network.
# Episode 14148	Average Score (last 100): 17.01	Epsilon: 0.0607	Total Steps: 1400207Updated target network.
# Episode 14149	Average Score (last 100): 17.21	Epsilon: 0.0607	Total Steps: 1400307Updated target network.
# Episode 14150	Average Score (last 100): 17.21	Epsilon: 0.0607	Total Steps: 1400407Updated target network.
# Episode 14151	Average Score (last 100): 17.21	Epsilon: 0.0607	Total Steps: 1400507Updated target network.
# Episode 14152	Average Score (last 100): 17.18	Epsilon: 0.0607	Total Steps: 1400607Updated target network.
# Episode 14153	Average Score (last 100): 17.37	Epsilon: 0.0607	Total Steps: 1400707Updated target network.
# Episode 14154	Average Score (last 100): 17.17	Epsilon: 0.0607	Total Steps: 1400807Updated target network.
# Episode 14155	Average Score (last 100): 17.17	Epsilon: 0.0607	Total Steps: 1400907Updated target network.
# Episode 14156	Average Score (last 100): 17.42	Epsilon: 0.0607	Total Steps: 1401007Updated target network.
# Episode 14157	Average Score (last 100): 17.42	Epsilon: 0.0607	Total Steps: 1401107Updated target network.
# Episode 14158	Average Score (last 100): 17.42	Epsilon: 0.0607	Total Steps: 1401207Updated target network.
# Episode 14159	Average Score (last 100): 17.11	Epsilon: 0.0607	Total Steps: 1401307Updated target network.
# Episode 14160	Average Score (last 100): 18.11	Epsilon: 0.0607	Total Steps: 1401407Updated target network.
# Episode 14161	Average Score (last 100): 18.10	Epsilon: 0.0607	Total Steps: 1401507Updated target network.
# Episode 14162	Average Score (last 100): 18.05	Epsilon: 0.0607	Total Steps: 1401607Updated target network.
# Episode 14163	Average Score (last 100): 18.03	Epsilon: 0.0606	Total Steps: 1401707Updated target network.
# Episode 14164	Average Score (last 100): 17.87	Epsilon: 0.0606	Total Steps: 1401807Updated target network.
# Episode 14165	Average Score (last 100): 17.97	Epsilon: 0.0606	Total Steps: 1401907Updated target network.
# Episode 14166	Average Score (last 100): 18.27	Epsilon: 0.0606	Total Steps: 1402007Updated target network.
# Episode 14167	Average Score (last 100): 18.26	Epsilon: 0.0606	Total Steps: 1402107Updated target network.
# Episode 14168	Average Score (last 100): 18.53	Epsilon: 0.0606	Total Steps: 1402207Updated target network.
# Episode 14169	Average Score (last 100): 18.33	Epsilon: 0.0606	Total Steps: 1402307Updated target network.
# Episode 14170	Average Score (last 100): 18.54	Epsilon: 0.0606	Total Steps: 1402407Updated target network.
# Episode 14171	Average Score (last 100): 18.44	Epsilon: 0.0606	Total Steps: 1402507Updated target network.
# Episode 14172	Average Score (last 100): 18.40	Epsilon: 0.0606	Total Steps: 1402607Updated target network.
# Episode 14173	Average Score (last 100): 18.40	Epsilon: 0.0606	Total Steps: 1402707Updated target network.
# Episode 14174	Average Score (last 100): 18.50	Epsilon: 0.0606	Total Steps: 1402807Updated target network.
# Episode 14176	Average Score (last 100): 18.37	Epsilon: 0.0606	Total Steps: 1402994Updated target network.
# Episode 14177	Average Score (last 100): 18.57	Epsilon: 0.0606	Total Steps: 1403094Updated target network.
# Episode 14178	Average Score (last 100): 18.37	Epsilon: 0.0606	Total Steps: 1403194Updated target network.
